# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
from sklearn import tree

iris = load_iris()

X = iris.data
y = iris.target

x_train , x_test , y_train , y_test = train_test_split(X, y , test_size = 0.20 , random_state =0)

# clf = tree.DecisionTreeClassifier(max_depth = 20 , random_state = 42 )

# clf.fit(x_train , y_train)

# plt.figure(figsize=(20,15))
# tree.plot_tree(clf , fontsize = 15 , filled = True , node_ids = True , rounded = True)
# plt.show()

# %%
print(tuple(iris.feature_names))
print(iris.target_names)
# Out:
# ('sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)')
# ['setosa' 'versicolor' 'virginica']

# %%
from dtreeviz.trees import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\XAN\Documents\dtree\try_dtree.ipynb Cell 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/XAN/Documents/dtree/try_dtree.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> from dtreeviz.trees import *
#
# ModuleNotFoundError: No module named 'dtreeviz'
